# %% [markdown]
# <h1 style = "text-align:center; front-size: 36px">Programación Concurrente y Distribuida </h1>
# <a href="https://github.com/mohamedoussamafarhat">
#     <img src="oussema foto.jpg" title = "Mohamed Oussama Farhat 22052494" alt="Mohamed Oussama Farhat 22052494" width="100" height="100" style="float:left;vertical-align:centre">
#     <img src="UEM-logo.png" title = "M21" alt="UE" width="105" height="105" style="float:right;vertical-align:centre">

# %% [markdown]
# ## THREADS ( CONCURRENCY )
#
#
#
#
#
# ### ENUNCIADO, Cree un programa para detemrinar:
# #### Con el objetivo de evitar ser detectado por los servidores a atacar y tomando en cuenta que queremos que el ataque sea "simultaneo", use hilos para que todos los ataques sean concurrentes
#
#
#
# 1. Crear platilla y portada para todos los ejercicios que realicemos a lo largo del curso.
# 2. Determine los tipos de respuesta de la parte cliente
# 3. El número de proceso que maneja y cuantos procesos están activos.
# 4. ¿Cuántos hilos activos tienes en este momento?
# 5. ¿Cuántos cores lógicos tiene tu equipo?
# 6. ¿Cuántos cores físicos tiene tu equipo?
# 7. Enumere e identifique los hilos lanzados.
# 8. Lance un ataque usando 20 hilos a: https://github.com/sukuzhanay
# 9. Lance un ataque usando 200 hilos a: https://www.youtube.com/UCEXbXdeafAjBahYK2hoQJFg
# 10. Lance un ataque usando 2000 hilos a: https://rpubs.com/christian_sucuzhanay
# 11. Lance un ataque usando 200000 hilos a: https://rpubs.com/christian_sucuzhanay
# 14. Lance un ataque usando 400 hilos a: https://eburnout.com/
# 15. ¿Que páginas logro "tumbar"?
# 16. Lance 20 hilos con el ping de la muerte al equipo de su compañero (a elegir)

# %%
import threading, os, platform, requests

# %%
from IPython import display

# %%
display.Image("ataque.png")

# %%
requests.get("https://github.com/sukuzhanay")
# Out:
# <Response [200]>

# %%
def ataque():
    requests.get("https://github.com/sukuzhanay")

# %%
threading.Thread(target=ataque())
# Out:
# <Thread(Thread-6, initial)>

# %% [markdown]
# # LISTA DE CODIGOS HTTP'S

# %%
url_="https://campus.europaeducationgroup.es/"

# %%
num_ataques=10_000_000

# %%
requests.get(url_)
# Out:
# <Response [401]>

# %%
display.Image("code.png")

# %%
res_=requests.get("https://github.com/sukuzhanay")

# %%
res_.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Sun, 28 Nov 2021 12:41:24 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Vary': 'X-Requested-With, X-PJAX-Container, Accept-Encoding, Accept, X-Requested-With', 'permissions-policy': 'interest-cohort=()', 'ETag': 'W/"09189816d57a635f5ff3e20085c134a9"', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Expect-CT': 'max-age=2592000, report-uri="https://api.github.com/_private/browser/errors"', 'Content-Security-Policy': "default-src 'none'; base-uri 'self'; block-all-mixed-content; child-src github.com/assets-cdn/worker/ gist.github.com/assets-cdn/worker/; connect-src 'self' uploads.github.com objects-origin.githubusercontent.com www.githubstatus.com collector.githubapp.com api.github.com github-cloud.s3.amazonaws.com github-production-repository-file-5c1aeb.s3.amazonaws.com github-production-upload-manifest-file-7fdce7.s3.amazonaws.com github-production-user-asset-6210df.s3.amazonaws.com cdn.optimizely.com logx.optimizely.com/v1/events translator.github.com wss://alive.github.com; font-src github.githubassets.com; form-action 'self' github.com gist.github.com objects-origin.githubusercontent.com; frame-ancestors 'none'; frame-src render.githubusercontent.com viewscreen.githubusercontent.com notebooks.githubusercontent.com; img-src 'self' data: github.githubassets.com identicons.github.com collector.githubapp.com github-cloud.s3.amazonaws.com secured-user-images.githubusercontent.com/ *.githubusercontent.com; manifest-src 'self'; media-src github.com user-images.githubusercontent.com/; script-src github.githubassets.com; style-src 'unsafe-inline' github.githubassets.com; worker-src github.com/assets-cdn/worker/ gist.github.com/assets-cdn/worker/", 'Content-Encoding': 'gzip', 'Set-Cookie': '_gh_sess=CKQode9CgfQx97lZjfZ5NIYNuChcWwvVVp8uXAvYf7rqeqtFZcp1f16RoMCY833%2B%2BUY9rxJfmK7AgHnOMoyQ1PWrFziRnQRTA7ILYgpfCd7MVy2up%2BQBBOaB4F7PsUfSLrpyYRcktcW8B59Q9iC1FbwaV0mndcGaoVRTiN%2FJ6ZoXO9mUeTJSoT87unHAVPqQPJKQVidQR1QUlriSHHWup6lDbqW%2F%2B%2FoFX5fwPTb55mVCgcYLWuzdDOolR32vyViXsvPZdR5OSjI%2Fn%2FjRyA5Bgw%3D%3D--0GpACq63vxM1GV1Z--90KOFygBUVk1OI3fdQ%2FCqw%3D%3D; Path=/; HttpOnly; Secure; SameSite=Lax, _octo=GH1.1.1810204104.1638103283; Path=/; Domain=github.com; Expires=Mon, 28 Nov 2022 12:41:23 GMT; Secure; SameSite=Lax, logged_in=no; Path=/; Domain=github.com; Expires=Mon, 28 Nov 2022 12:41:23 GMT; HttpOnly; Secure; SameSite=Lax', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'AA40:4D82:32FB1A:559789:61A378F3'}

# %%
contenido=res_.text

# %%
def throw():
    requests.get(url)
    threading.current_thread()

# %%
threading.Thread(target=throw)
# Out:
# <Thread(Thread-7, initial)>

# %%
for i in range(num_ataques):
    threading.Th
